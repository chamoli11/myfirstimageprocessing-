# %% [markdown]
# <a href="https://colab.research.google.com/github/chamoli11/myfirstimageprocessing-/blob/main/image_processing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://rukminim1.flixcart.com/image/416/416/poster/f/h/z/cute-puppy-in-white-poster-stst968-large-original-imaefgecrvnmanyk.jpeg?q=70'
# Out:
# --2022-07-21 11:12:58--  https://rukminim1.flixcart.com/image/416/416/poster/f/h/z/cute-puppy-in-white-poster-stst968-large-original-imaefgecrvnmanyk.jpeg?q=70
# Resolving rukminim1.flixcart.com (rukminim1.flixcart.com)... 104.85.5.60
# Connecting to rukminim1.flixcart.com (rukminim1.flixcart.com)|104.85.5.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13650 (13K) [image/jpeg]
# Saving to: ‘cute-puppy-in-white-poster-stst968-large-original-imaefgecrvnmanyk.jpeg?q=70’
#
# cute-puppy-in-white 100%[===================>]  13.33K  --.-KB/s    in 0s
#
# 2022-07-21 11:12:58 (274 MB/s) - ‘cute-puppy-in-white-poster-stst968-large-original-imaefgecrvnmanyk.jpeg?q=70’ saved [13650/13650]

# %% [markdown]
# # libraries used for image processing
# matplotlib.images
# pillow
# opencv(cv2)

# %% [markdown]
# # New Section

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading iamge through matplotlib.image module

img= mpimg.imread('/content/cute-puppy-in-white-poster-stst968-large-original-imaefgecrvnmanyk.jpeg?q=70')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (312, 416, 3)

# %%
print(img)
# Out:
# [[[ 49 105 106]
#   [ 39  97  98]
#   [ 35  93  94]
#   ...
#   [  3  60  77]
#   [  3  60  77]
#   [  2  59  76]]
#
#  [[ 49 105 106]
#   [ 40  98  99]
#   [ 35  93  94]
#   ...
#   [  3  60  77]
#   [  3  60  77]
#   [  3  60  77]]
#
#  [[ 50 106 107]
#   [ 41  99 100]
#   [ 36  94  95]
#   ...
#   [  3  60  77]
#   [  3  60  77]
#   [  3  60  77]]
#
#  ...
#
#  [[122 134  70]
#   [122 134  70]
#   [123 135  71]
#   ...
#   [ 76  99  27]
#   [ 75  98  28]
#   [ 74  97  27]]
#
#  [[118 130  66]
#   [118 130  66]
#   [119 131  67]
#   ...
#   [ 76  99  27]
#   [ 75  98  28]
#   [ 74  97  27]]
#
#  [[116 128  64]
#   [116 128  64]
#   [117 129  65]
#   ...
#   [ 76  99  27]
#   [ 75  98  28]
#   [ 74  97  27]]]

# %%
# display image from numpy array
img_plot= plt.imshow(img)

# %%
from PIL import Image

# %%
img= Image.open('/content/cute-puppy-in-white-poster-stst968-large-original-imaefgecrvnmanyk.jpeg?q=70')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog.jpg')

# %%
img_res= mpimg.imread('/content/dog.jpg')
img.plot= plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img= cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
grayscale_img= cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_img)
# Out:
# numpy.ndarray

# %%
print(grayscale_img)
# Out:
# [[ 95  90  88 ...  60  59  59]
#  [ 96  90  88 ...  61  59  59]
#  [ 96  91  89 ...  61  60  59]
#  ...
#  [120 120 120 ...  76  75  75]
#  [114 114 115 ...  76  76  75]
#  [109 110 110 ...  76  76  75]]

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_img)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7FE7BB355550>

# %%
cv2.imwrite('dog_gray.jpg', grayscale_img)
# Out:
# True

# %%
print(grayscale_img.shape)
# Out:
# (200, 200)
